# %%
import pandas as pd

url_estacionalidad = "https://raw.githubusercontent.com/agmcsv/analisis-arandanos-huelva/main/datos/Estacionalidad_Produccion_Arandanos.csv"
df_estacionalidad = pd.read_csv(url_estacionalidad)
print("Estacionalidad cargado:", df_estacionalidad.shape)
df_estacionalidad.head()
# Out:
# Estacionalidad cargado: (7, 2)
#        Mes Porcentaje Estimado de Producción (%)
# 0    Enero                                    1%
# 1  Febrero                                    3%
# 2    Marzo                                   10%
# 3    Abril                                   35%
# 4     Mayo                                   36%

# %%
url_municipios = "https://raw.githubusercontent.com/agmcsv/analisis-arandanos-huelva/main/datos/Municipios_Produccion_Arandanos_Huelva.csv"
df_municipios = pd.read_csv(url_municipios)
print("Municipios cargado:", df_municipios.shape)
df_municipios.head()
# Out:
# Municipios cargado: (7, 2)
#            Municipio  Superficie Estimada de Arándanos (ha)
# 0             Moguer                                   1000
# 1            Almonte                                    800
# 2               Lepe                                    600
# 3            Cartaya                                    500
# 4  Lucena del Puerto                                    400

# %%
import pandas as pd

url_produccion = "https://raw.githubusercontent.com/agmcsv/analisis-arandanos-huelva/main/datos/produccion_arandanos_mejorado_huelva.csv"
df_produccion = pd.read_csv(url_produccion)

df_produccion.head()
# Out:
#     Año  Superficie Cultivada (ha)  Producción Total (toneladas)  \
# 0  2015                       1150                         10000
# 1  2016                       1200                         11000
# 2  2017                       2500                         20000
# 3  2018                       2800                         22500
# 4  2019                       3000                         25000
#
#    Rendimiento por Hectárea (toneladas/ha) Área por Zona Método de Cultivo  \
# 0                                      8.7         Costa      Convencional
# 1                                      9.2      Interior      Convencional
# 2                                      8.0         Costa         Ecológico
# 3                                      8.0      Interior      Convencional
# 4                                      8.3         Costa         Ecológico
#
#    Precio Medio (€/kg)
# 0                  2.5
# 1                  2.6
# 2                  3.0
# 3                  2.8
# ...

# %%
url_precios = "https://raw.githubusercontent.com/agmcsv/analisis-arandanos-huelva/main/datos/Precios_Arandanos_Huelva_2015_2024.csv"
df_precios = pd.read_csv(url_precios, sep=';')
print("Precios cargado:", df_precios.shape)
df_precios.head()
# Out:
# Precios cargado: (12, 1)
#   Año   Precio Medio (€/kg)  | Fuente
# 0  | ---- | ------------------- | ---------------...
# 1  | 2015 | 3,47                | [Infoagro]     ...
# 2  | 2016 | 4,05                | [Infoagro]     ...
# 3  | 2017 | 4,06                | [Freshplaza]   ...
# 4  | 2018 | 3,45                | [Freshplaza]   ...

# %%
url_variedades = "https://raw.githubusercontent.com/agmcsv/analisis-arandanos-huelva/main/datos/arandanos_variedades_huelva.csv"
df_variedades = pd.read_csv(url_variedades)
print("Variedades cargado:", df_variedades.shape)
df_variedades.head()
# Out:
# Variedades cargado: (10, 4)
#    Variedad  Año_Siembra  Area_Cultivada_ha  Rendimiento_Toneladas_ha
# 0  Bluecrop         2015                150                       8.2
# 1      Duke         2016                160                       7.5
# 2    Legacy         2017                180                       8.0
# 3   Patriot         2018                170                       7.8
# 4   Emerald         2019                190                       8.5

# %%
url_clima = "https://raw.githubusercontent.com/agmcsv/analisis-arandanos-huelva/main/datos/datos_clima_arandanos_huelva_2015_2024.csv"
df_clima = pd.read_csv(url_clima)
print("Clima cargado:", df_clima.shape)
df_clima.head()
# Out:
# Clima cargado: (10, 5)
#     Año  Precipitación media (feb-jun) [mm]  \
# 0  2015                                 250
# 1  2016                                 260
# 2  2017                                 240
# 3  2018                                 230
# 4  2019                                 220
#
#    Temperatura promedio (abr-may) [°C]  \
# 0                                 17.5
# 1                                 18.0
# 2                                 18.5
# 3                                 19.0
# 4                                 19.5
#
#    Exportaciones de arándanos [toneladas]  pH del suelo
# 0                                   24600           4.6
# 1                                   30000           4.7
# 2                                   35000           4.8
# 3                                   40000           4.7
# 4                                   45000           4.9

# %%
url_exportadores = "https://raw.githubusercontent.com/agmcsv/analisis-arandanos-huelva/main/datos/top_paises_exportadores_por_a%C3%B1o_2015_2024.csv"
df_exportadores = pd.read_csv(url_exportadores, encoding='utf-8')

print("Exportadores cargado:", df_exportadores.shape)
df_exportadores.head()
# Out:
# Exportadores cargado: (10, 3)
#                      País   Año  Toneladas Exportadas
# 0            Países Bajos  2015                  6932
# 1  Emiratos Árabes Unidos  2016                  6795
# 2                  EE.UU.  2017                  6989
# 3                  Canadá  2018                  6565
# 4                  Canadá  2019                  6794
