# %%
import pandas as pd
from IPython.display import Image, display

url_csv = "https://raw.githubusercontent.com/agmcsv/analisis-arandanos-huelva/main/predicciones/tabla_predicciones_optimista_2025_2027.csv"
df_predicciones = pd.read_csv(url_csv, encoding='utf-8')
df_predicciones.columns = df_predicciones.columns.str.strip()

print("Predicciones optimistas 2025-2027:")
display(df_predicciones.head())

img_path = "https://raw.githubusercontent.com/agmcsv/analisis-arandanos-huelva/main/predicciones/proyeccion_arandano_2025_2030_simple.png"
print("Gráfico proyección 2025-2030:")
display(Image(url=img_path, width=700))

print("""
Resumen:
Este notebook muestra las predicciones optimistas de producción de arándanos para los años 2025-2027 basadas en tendencias pasadas,
junto con una proyección visual para el periodo 2025-2030.
""")
# Out:
# Predicciones optimistas 2025-2027:
#     Año  Produccion_total_predicha  Precio_estimado_€/tonelada  \
# 0  2025                      72733                        3900
# 1  2026                      74958                        4000
# 2  2027                      77182                        4100
#
#    Rendimiento promedio (t/ha)  % Exportación estimada  \
# 0                         14.5                    84.0
# 1                         15.0                    85.0
# 2                         15.5                    86.0
#
#    Exportación estimada (toneladas)  Consumo nacional estimado (toneladas)
# 0                             61095                                  11638
# 1                             63714                                  11244
# 2                             66376                                  10806
# Gráfico proyección 2025-2030:
# ...
